# %% [markdown]
# <a href="https://colab.research.google.com/github/MdShajalalsojib/Data-Mining-Lab/blob/main/PCA_TSNE_006_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
digits = datasets.load_digits()
X = digits.data
# X
y = digits.target
# y

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)
X_pca
# Out:
# array([[ -1.25946645, -21.27488348],
#        [  7.9576113 ,  20.76869896],
#        [  6.99192297,   9.95598641],
#        ...,
#        [ 10.8012837 ,   6.96025223],
#        [ -4.87210009, -12.42395362],
#        [ -0.34438963,  -6.36554919]])

# %%
plt.scatter(X_pca[:,0],X_pca[:,1],c=y, cmap='jet',edgecolors='k')
plt.colorbar()
plt.title("PCA Visualization")
plt.show()

# %% [markdown]
# # **T-SNE**

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2,perplexity=30, n_iter=700)

# %%
X_tsne = tsne.fit_transform(X)
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
X_tsne
# Out:
# array([[ -2.6477075, -43.691303 ],
#        [  9.629161 ,   9.695813 ],
#        [-12.615278 ,  17.456047 ],
#        ...,
#        [ -5.418357 ,   9.83684  ],
#        [-18.977974 , -13.851947 ],
#        [-12.953899 ,   6.520756 ]], dtype=float32)

# %%
plt.scatter(X_tsne[:,0],X_tsne[:,1],c=y, cmap='jet', edgecolors='k')
plt.colorbar()
plt.title("TSNE Visualization")
plt.show()
