# %% [markdown]
# <a href="https://colab.research.google.com/github/MdShajalalsojib/Data-Mining-Lab/blob/main/Visualization_005.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Ataullha/CSE-436-Data-Mining-Lab/refs/heads/main/titanic_train.csv")

# %%
df.head(2)
# Out:
#    passenger_id  pclass                name     sex   age  sibsp  parch  \
# 0          1216       3  Smyth, Miss. Julia  female   NaN      0      0
# 1           699       3     Cacic, Mr. Luka    male  38.0      0      0
#
#    ticket    fare cabin embarked boat  body home.dest  survived
# 0  335432  7.7333   NaN        Q   13   NaN       NaN         1
# 1  315089  8.6625   NaN        S  NaN   NaN   Croatia         0

# %%
df['age'] = df['age'].fillna(df['age'].mean())

# %%
df['age'].isnull().sum()
# Out:
# np.int64(0)

# %%
data = df[['age']]

# %%
sns.catplot(data=data,kind='box')

# %%
data.describe()
# Out:
#               age
# count  850.000000
# mean    29.519847
# std     12.984533
# min      0.166700
# 25%     22.000000
# 50%     29.519847
# 75%     34.875000
# max     80.000000

# %%
sns.catplot(data=data,kind='violin')

# %%
sns.catplot(x='sex',y='survived',kind='bar',data=df)

# %%
sns.catplot(x='sex',y='survived',hue='pclass',kind='bar',data=df)

# %%
sns.pairplot(df)

# %%
sns.jointplot(df[['age','fare']])

# %%
df['age'].corr(df['fare'])
# Out:
# np.float64(0.1884379033684345)

# %%
matrix = df[['age','fare']].corr()

# %%
sns.heatmap(matrix,annot=True,cmap='PuOr')
plt.title("Demo Heatmap")
plt.savefig("demo.pdf",dpi=6000)

# %%
sns.histplot(data,bins=4,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
x = [1,2,3]
y = [2,4,6]
plt.plot(x,y)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("X and Y Plot")
plt.show()
