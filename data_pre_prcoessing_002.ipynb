# %% [markdown]
# <a href="https://colab.research.google.com/github/MdShajalalsojib/Data-Mining-Lab/blob/main/data_pre_prcoessing_002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas --q

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Ataullha/CSE-412_Machine-Learning-Lab/refs/heads/main/titanic_train.csv")

# %%
df.head(2)
df.tail()
df.sample(5)
# Out:
#      passenger_id  pclass                                               name  \
# 133          1180       3                     Sage, Mrs. John (Annie Bullen)
# 226          1187       3                    Sandstrom, Miss. Beatrice Irene
# 211           424       2                        Givard, Mr. Hans Kristensen
# 388          1073       3                              O'Connor, Mr. Maurice
# 160            83       1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
#
#         sex   age  sibsp  parch    ticket   fare cabin embarked boat   body  \
# 133  female   NaN      1      9  CA. 2343  69.55   NaN        S  NaN    NaN
# 226  female   1.0      1      1   PP 9549  16.70    G6        S   13    NaN
# 211    male  30.0      0      0    250646  13.00   NaN        S  NaN  305.0
# 388    male   NaN      0      0    371060   7.75   NaN        Q  NaN    NaN
# 160  female  64.0      1      1    112901  26.55   B26        S    7    NaN
#
#          home.dest  survived
# 133            NaN         0
# 226            NaN         1
# 211            NaN         0
# 388            NaN         0
# 160  Milwaukee, WI         1

# %%
len(df.columns)
len(df)
# Out:
# 850

# %%
df.shape
# Out:
# (850, 15)

# %%
type(df['age'])
# Out:
# pandas.core.series.Series

# %%
type(df[['age']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['age']
# Out:
# 0       NaN
# 1      38.0
# 2      30.0
# 3      54.0
# 4      40.0
#        ...
# 845    55.0
# 846    58.0
# 847    24.0
# 848     3.0
# 849    52.0
# Name: age, Length: 850, dtype: float64

# %%
df['age'].isnull().sum()
# Out:
# np.int64(174)

# %%
df['age'] = df['age'].fillna(df['age'].mean())

df['age'] = df['age'].fillna(df['age'].median())
df['age'] = df['age'].fillna(df['age'].mode())
df['age'] = df['age'].fillna(df['age'].min())
df['age'] = df['age'].fillna(df['age'].max())

# %%
df['age'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['passenger_id', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest',
#        'survived'],
#       dtype='object')

# %%
# df = df.drop("name",axis=1)

df.drop("name",axis=1,inplace=True)

# %%
len(df.columns)
# Out:
# 14

# %%
df.describe()
# Out:
#        passenger_id     pclass         age       sibsp       parch  \
# count    850.000000  850.00000  850.000000  850.000000  850.000000
# mean     662.816471    2.32000   29.519847    0.522353    0.382353
# std      380.751936    0.83853   12.984533    1.112132    0.879511
# min        1.000000    1.00000    0.166700    0.000000    0.000000
# 25%      332.250000    2.00000   22.000000    0.000000    0.000000
# 50%      676.500000    3.00000   29.519847    0.000000    0.000000
# 75%      992.250000    3.00000   34.875000    1.000000    0.000000
# max     1307.000000    3.00000   80.000000    8.000000    9.000000
#
#              fare        body    survived
# count  849.000000   73.000000  850.000000
# mean    34.012701  165.821918    0.368235
# std     53.705779   99.068487    0.482610
# min      0.000000    4.000000    0.000000
# 25%      7.895800   75.000000    0.000000
# 50%     14.108300  166.000000    0.000000
# 75%     31.000000  260.000000    1.000000
# max    512.329200  328.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   passenger_id  850 non-null    int64
#  1   pclass        850 non-null    int64
#  2   sex           850 non-null    object
#  3   age           850 non-null    float64
#  4   sibsp         850 non-null    int64
#  5   parch         850 non-null    int64
#  6   ticket        850 non-null    object
#  7   fare          849 non-null    float64
#  8   cabin         191 non-null    object
#  9   embarked      849 non-null    object
#  10  boat          308 non-null    object
#  11  body          73 non-null     float64
#  12  home.dest     464 non-null    object
#  13  survived      850 non-null    int64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 93.1+ KB

# %%
df['age'] = (df['age'] - df['age'].min())/(df['age'].max()-df['age'].min())

# %%
sum(df['age']>=1)
# Out:
# 1

# %%
df[df['age']==df['age'].max()]['cabin']
# Out:
# 177    A23
# Name: cabin, dtype: object

# %%
df['age'] = (df['age'] - df['age'].mean())/(df['age'].std())

# %%
df['age'].std()
df['age'].mean()
# Out:
# np.float64(-1.9226450497038004e-16)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
le = LabelEncoder()
oe = OrdinalEncoder()
df['sex'] = le.fit_transform(df['sex'])
df['sex'] = oe.fit_transform(df[['sex']])

# %%
df['sex']
# Out:
# 0      0.0
# 1      1.0
# 2      0.0
# 3      0.0
# 4      1.0
#       ...
# 845    1.0
# 846    1.0
# 847    0.0
# 848    0.0
# 849    1.0
# Name: sex, Length: 850, dtype: float64

# %%
df['sex']
# Out:
# 0      0.0
# 1      1.0
# 2      0.0
# 3      0.0
# 4      1.0
#       ...
# 845    1.0
# 846    1.0
# 847    0.0
# 848    0.0
# 849    1.0
# Name: sex, Length: 850, dtype: float64

# %%
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder()
ohe.fit_transform(df[['sex']]).toarray()
ohe.get_feature_names_out()
ohe_df = pd.DataFrame(
    ohe.fit_transform(df[['sex']]).toarray(),
     columns=ohe.get_feature_names_out()
 )
df = pd.concat([df,ohe_df],axis=1)
df
# Out:
#      passenger_id  pclass  sex       age  sibsp  parch              ticket  \
# 0            1216       3  0.0  0.000000      0      0              335432
# 1             699       3  1.0  0.653096      0      0              315089
# 2            1267       3  0.0  0.036979      1      1              345773
# 3             449       2  0.0  1.885332      1      3               29105
# 4             576       2  1.0  0.807126      0      0               28221
# ..            ...     ...  ...       ...    ...    ...                 ...
# 845           158       1  1.0  1.962347      0      0                 680
# 846           174       1  1.0  2.193391      0      0               11771
# 847           467       2  0.0 -0.425109      1      0              244367
# 848          1112       3  0.0 -2.042418      1      1  SOTON/O.Q. 3101315
# 849           425       2  1.0  1.731302      0      0              250647
#
#         fare cabin embarked boat   body                 home.dest  survived  \
# 0     7.7333   NaN        Q   13    NaN                       NaN         1
# 1     8.6625   NaN        S  NaN    NaN                   Croatia         0
# 2    24.1500   NaN        S  NaN    NaN                       NaN         0
# 3    23.0000   NaN        S    4    NaN      Cornwall / Akron, OH         1
# 4    13.0000   NaN        S  NaN    NaN  Barre, Co Washington, VT         0
# ..       ...   ...      ...  ...    ...                       ...       ...
# 845  50.0000   C39        S  NaN    NaN       London / Birmingham         0
# 846  29.7000   B37        C  NaN  258.0               Buffalo, NY         0
# 847  26.0000   NaN        S   12    NaN        Moscow / Bronx, NY         1
# 848  13.7750   NaN        S  NaN    NaN                       NaN         0
# 849  13.0000   NaN        S  NaN   19.0                 Bronx, NY         0
#
#      sex_0.0  sex_1.0
# 0        1.0      0.0
# 1        0.0      1.0
# 2        1.0      0.0
# 3        1.0      0.0
# 4        0.0      1.0
# ..       ...      ...
# 845      0.0      1.0
# 846      0.0      1.0
# 847      1.0      0.0
# 848      1.0      0.0
# 849      0.0      1.0
#
# [850 rows x 16 columns]

# %%
df.head()
# Out:
#    passenger_id  pclass  sex       age  sibsp  parch  ticket     fare cabin  \
# 0          1216       3  0.0  0.000000      0      0  335432   7.7333   NaN
# 1           699       3  1.0  0.653096      0      0  315089   8.6625   NaN
# 2          1267       3  0.0  0.036979      1      1  345773  24.1500   NaN
# 3           449       2  0.0  1.885332      1      3   29105  23.0000   NaN
# 4           576       2  1.0  0.807126      0      0   28221  13.0000   NaN
#
#   embarked boat  body                 home.dest  survived  sex_0.0  sex_1.0
# 0        Q   13   NaN                       NaN         1      1.0      0.0
# 1        S  NaN   NaN                   Croatia         0      0.0      1.0
# 2        S  NaN   NaN                       NaN         0      1.0      0.0
# 3        S    4   NaN      Cornwall / Akron, OH         1      1.0      0.0
# 4        S  NaN   NaN  Barre, Co Washington, VT         0      0.0      1.0

# %%
df = df[['pclass','sex']]

# %%
df
# Out:
#      pclass  sex
# 0         3  0.0
# 1         3  1.0
# 2         3  0.0
# 3         2  0.0
# 4         2  1.0
# ..      ...  ...
# 845       1  1.0
# 846       1  1.0
# 847       2  0.0
# 848       3  0.0
# 849       2  1.0
#
# [850 rows x 2 columns]

# %%
df = pd.get_dummies(df,dtype=int)

# %%
df
# Out:
#      pclass  sex
# 0         3  0.0
# 1         3  1.0
# 2         3  0.0
# 3         2  0.0
# 4         2  1.0
# ..      ...  ...
# 845       1  1.0
# 846       1  1.0
# 847       2  0.0
# 848       3  0.0
# 849       2  1.0
#
# [850 rows x 2 columns]

# %% [markdown]
# **Min-Max Feature Scaling**

# %%
import pandas as pd

# Create data
df = pd.DataFrame([
    [180000, 110, 18.9, 1400],
    [360000, 905, 23.4, 1800],
    [230000, 230, 14.0, 1300],
    [60000, 450, 13.5, 1500]
], columns=['Col A', 'Col B', 'Col C', 'Col D'])

df_min_max_scaled = df.copy()

# Apply normalization technique
for column in df_min_max_scaled.columns:
    df_min_max_scaled[column] = (
        df_min_max_scaled[column] - df_min_max_scaled[column].min()
    ) / (
        df_min_max_scaled[column].max() - df_min_max_scaled[column].min()
    )

# View normalized data
print(df_min_max_scaled)
# Out:
#       Col A     Col B     Col C  Col D
# 0  0.400000  0.000000  0.545455    0.2
# 1  1.000000  1.000000  1.000000    1.0
# 2  0.566667  0.150943  0.050505    0.0
# 3  0.000000  0.427673  0.000000    0.4

# %% [markdown]
# # **Z-Score Method**

# %%
# Create a copy of the data
df_z_score = df.copy()

# Apply Z-Score normalization
for column in df_z_score.columns:
    df_z_score[column] = (
        df_z_score[column] - df_z_score[column].mean()
    ) / df_z_score[column].std()

# View normalized data
print(df_z_score)
# Out:
#       Col A     Col B     Col C    Col D
# 0 -0.221422 -0.895492  0.311486 -0.46291
# 1  1.227884  1.373564  1.278167  1.38873
# 2  0.181163 -0.552993 -0.741122 -0.92582
# 3 -1.187625  0.074922 -0.848531  0.00000
