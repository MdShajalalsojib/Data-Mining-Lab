# %% [markdown]
# <a href="https://colab.research.google.com/github/MdShajalalsojib/Data-Mining-Lab/blob/main/python_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
n = 100
m = 50
# print("This is n: "+str(n))
# print(f"This is n: {n}, and m: {m}")
print("This is n:",n)
# Out:
# This is n: 100

# %%
print('He said, "I eat rice.')
print('''
I
eat
rice
''')
# Out:
# He said, "I eat rice.
#
# I
# eat
# rice

# %%
fn = 'DM'
ln = 'Lab'
full_name = fn+" "+ln
print(full_name)
# Out:
# DM Lab

# %%
(full_name+' ')*3
# Out:
# 'DM Lab DM Lab DM Lab '

# %%
n = 100
# typecast
str(n)
float(n)

bool(n)

bool(0)
bool([])
bool('')
# Out:
# False

# %%
pi = 3.14
off = True
type(pi)
# Out:
# float

# %%
n, m = map(int,input().split())
n, m
# Out:
# 32
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_537/183224161.py in <cell line: 0>()
# ----> 1 n, m = map(int,input().split())
#       2 n, m
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
pow(3,2,5) # 9%5 = 4
# Out:
# 4

# %%
x = 3
y = 2
print(x!=y)
print(x==y)
# Out:
# True
# False

# %%
thisList = ["A","B","A","C"]
len(thisList)
# thisList[len(thisList)-1]
thisList[-1]
# Out:
# 'C'

# %%
name = "datamining"
'''
name[start:end+1]
output => name[start:end]
'''
name[1:4] # ata
# Out:
# 'ata'

# %%
print(name[-4:-2]) # output
print(name[-2:-4]) # no output
# Out:
# ni

# %%
name = ['d','a','t','a']
name[1] = 'u'
name[2:4] = ['o','o']
name
name[2:] = ['p','q']
name
# Out:
# ['d', 'u', 'p', 'q']

# %%
# list operations
name = ['d','a','t','a']

name.append('m')
name
name.insert(1,'q')
name

name.remove('a')
name
name.pop(3)
name
# Out:
# ['d', 'q', 't', 'm']

# %%
# numpy vs normal list

a = [1,2,3]
b = [4,5,6]
c = a+b
d = c*2
d
# Out:
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]

# %%
a = 2
b = 3

if a>b:
    print("A is greater")
elif a<b:
    print("B is greater")
else:
    print("A and B are equal")
# Out:
# B is greater

# %%
a = 2
b = 3

print("A") if a>b else print("B")
# Out:
# B
